# %%
import pandas as pd

# %% [markdown]
# Comando para leer csv, delmiter = 'separador', header = fila que sería el encabezado (0, 1, 2...), names = headers

# %%
df_books = pd.read_csv('dataframes/bestsellers-with-categories.csv', delimiter = ',', header = 0, names = ['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Para ver las columnas del df hacemos lo siguiente

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# Data no estructurada, archivos .json

# %%
df_json = pd.read_json('dataframes/hpcharactersdataraw.json', typ = 'Series')
df_json
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %% [markdown]
# ## Reto: leer un dataframe personal y resaltar cosas importantes

# %%
mov_masa = pd.read_csv('dataframes/REPORTE__DE_EVENTOS_POR_DESASTRES_NATURALES_Y_ANTR_PICOS.csv', delimiter = ',', header = 0)
mov_masa
# Out:
#      ITEM                   FECHA                EVENTO             MUNICIPIO  \
# 0       1  01/02/2023 12:00:00 AM    MOVIMIENTO EN MASA               LEBRIJA
# 1       2  01/02/2023 12:00:00 AM    MOVIMIENTO EN MASA         FLORIDABLANCA
# 2       3  01/25/2023 12:00:00 AM               HELADAS                  TONA
# 3       4  01/25/2023 12:00:00 AM               HELADAS               CERRITO
# 4       5  01/28/2023 12:00:00 AM     INCENDIO FORESTAL             EL PLAYON
# ..    ...                     ...                   ...                   ...
# 97     98  07/13/2023 12:00:00 AM     INCENDIO FORESTAL           PIEDECUESTA
# 98     99  07/17/2023 12:00:00 AM               EROSION        PUERTO WILCHES
# 99    100  07/19/2023 12:00:00 AM     INCENDIO FORESTAL               EL HATO
# 100   101  07/22/2023 12:00:00 AM  TORMENTAS ELECTRICAS  EL CARMEN DE CHUCURI
# 101   102  07/25/2023 12:00:00 AM  TORMENTAS ELECTRICAS              OCAMONTE
#
# ...
